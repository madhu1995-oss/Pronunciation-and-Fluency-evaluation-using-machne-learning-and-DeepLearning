# %%
import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import soundfile as sf


def feature_extraction(file_name):
   
    X , sample_rate = librosa.load(file_name, sr=None) 
    if X.ndim > 1:
        X = X[:,0]
    X = X.T
    stft = np.abs(librosa.stft(X))       
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=20).T, axis=0) 
    rmse = np.mean(librosa.feature.rms(y=X).T, axis=0) 
    spectral_flux = np.mean(librosa.onset.onset_strength(y=X, sr=sample_rate).T, axis=0) 
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=X).T, axis=0) 
    return mfccs, rmse, spectral_flux, zcr
    
def parse_audio_files(parent_dir, sub_dirs, file_ext='*.wav'): 
    n_mfccs = 20 
    number_of_features = 3 + n_mfccs
    features, labels = np.empty((0,number_of_features)), np.empty(0)
    for label, sub_dir in enumerate(sub_dirs): 
        for file_name in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)): 
            print ("Actual File Name: ", file_name)
            try:
                mfccs, rmse, spectral_flux, zcr = feature_extraction(file_name)
            except Exception as e:
                print("[Error] there was an error in feature extraction. %s" % (e))
                continue 
            extracted_features = np.hstack([mfccs, rmse, spectral_flux, zcr])
            features = np.vstack([features, extracted_features])
            labels = np.append(labels, label)
        print("Extracted features from %s, done" % (sub_dir))
    return np.array(features), np.array(labels, dtype = np.int)

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
#Read audio classes directories
import os
audio_subdirectories = os.listdir("/content/audio-data/audio-data")
audio_subdirectories.sort()
print ('Audio Subdirs: ', audio_subdirectories)
# Out:
# Audio Subdirs:  ['high', 'low_1']

# %%
from os import walk
from os import path

for (dirpath, dirnames, filenames) in walk("/content/drive/MyDrive/audio-data/high/"):
  print(filenames)
  for i in range(len(filenames)):
    os.rename("/content/drive/MyDrive/audio-data/high/"+filenames[i],"/content/drive/MyDrive/audio-data/high/"+filenames[i] + '.mp3')
# Out:
# ['Avalinguo - Dana and Konay segment 1 - D (443)', 'Avalinguo - Dana and Konay segment 1 - D (442)', 'Avalinguo - Dana and Konay segment 1 - D (441)', 'Avalinguo - Dana and Konay segment 1 - D (445)', 'Avalinguo - Dana and Konay segment 1 - D (444)', 'Avalinguo - Dana and Konay segment 1 - D (446)', 'Avalinguo - Dana and Konay segment 1 - D (440)', 'Avalinguo - Dana and Konay segment 1 - D (439)', 'Avalinguo - Dana and Konay segment 1 - D (1)', 'Avalinguo - Dana and Konay segment 1 - D', 'Avalinguo - Dana and Konay segment 1 - D (511)', 'Avalinguo - Dana and Konay segment 1 - D (505)', 'Avalinguo - Dana and Konay segment 1 - D (504)', 'Avalinguo - Dana and Konay segment 1 - D (503)', 'Avalinguo - Dana and Konay segment 1 - D (502)', 'Avalinguo - Dana and Konay segment 1 - D (501)', 'Avalinguo - Dana and Konay segment 1 - D (497)', 'Avalinguo - Dana and Konay segment 1 - D (496)', 'Avalinguo - Dana and Konay segment 1 - D (495)', 'Avalinguo - Dana and Konay segment 1 - D (494)', 'Avalinguo - Dana and Konay segment 1 - D (498)', 'Avalinguo - Dana and Konay segment 1 - D (500)', 'Avalinguo - Dana and Konay segment 1 - D (493)', 'Avalinguo - Dana and Konay segment 1 - D (492)', 'Avalinguo - Dana and Konay segment 1 - D (491)', 'Avalinguo - Dana and Konay segment 1 - D (499)', 'Avalinguo - Dana and Konay segment 1 - D (490)', 'Avalinguo - Dana and Konay segment 1 - D (489)', 'Avalinguo - Dana and Konay segment 1 - D (487)', 'Avalinguo - Dana and Konay segment 1 - D (488)', 'Avalinguo - Dana and Konay segment 1 - D (484)', 'Avalinguo - Dana and Konay segment 1 - D (485)', 'Avalinguo - Dana and Konay segment 1 - D (486)', 'Avalinguo - Dana and Konay segment 1 - D (483)', 'Avalinguo - Dana and Konay segment 1 - D (482)', 'Avalinguo - Dana and Konay segment 1 - D (481)', 'Avalinguo - Dana and Konay segment 1 - D (479)', 'Avalinguo - Dana and Konay segment 1 - D (480)', 'Avalinguo - Dana and Konay segment 1 - D (474)', 'Avalinguo - Dana and Konay segment 1 - D (472)', 'Avalinguo - Dana and Konay segment 1 - D (476)', 'Avalinguo - Dana and Konay segment 1 - D (473)', 'Avalinguo - Dana and Konay segment 1 - D (478)', 'Avalinguo - Dana and Konay segment 1 - D (475)', 'Avalinguo - Dana and Konay segment 1 - D (477)', 'Avalinguo - Dana and Konay segment 1 - D (471)', 'Avalinguo - Dana and Konay segment 1 - D (470)', 'Avalinguo - Dana and Konay segment 1 - D (469)', 'Avalinguo - Dana and Konay segment 1 - D (467)', 'Avalinguo - Dana and Konay segment 1 - D (468)', 'Avalinguo - Dana and Konay segment 1 - D (464)', 'Avalinguo - Dana and Konay segment 1 - D (465)', 'Avalinguo - Dana and Konay segment 1 - D (461)', 'Avalinguo - Dana and Konay segment 1 - D (463)', 'Avalinguo - Dana and Konay segment 1 - D (462)', 'Avalinguo - Dana and Konay segment 1 - D (466)', 'Avalinguo - Dana and Konay segment 1 - D (460)', 'Avalinguo - Dana and Konay segment 1 - D (459)', 'Avalinguo - Dana and Konay segment 1 - D (458)', 'Avalinguo - Dana and Konay segment 1 - D (457)', 'Avalinguo - Dana and Konay segment 1 - D (456)', 'Avalinguo - Dana and Konay segment 1 - D (454)', 'Avalinguo - Dana and Konay segment 1 - D (452)', 'Avalinguo - Dana and Konay segment 1 - D (453)', 'Avalinguo - Dana and Konay segment 1 - D (449)', 'Avalinguo - Dana and Konay segment 1 - D (455)', 'Avalinguo - Dana and Konay segment 1 - D (451)', 'Avalinguo - Dana and Konay segment 1 - D (450)', 'Avalinguo - Dana and Konay segment 1 - D (448)', 'Avalinguo - Dana and Konay segment 1 - D (447)', 'Avalinguo - Dana and Konay segment 1 - D (546)', 'Avalinguo - Dana and Konay segment 1 - D (545)', 'Avalinguo - Dana and Konay segment 1 - D (543)', 'Avalinguo - Dana and Konay segment 1 - D (544)', 'Avalinguo - Dana and Konay segment 1 - D (542)', 'Avalinguo - Dana and Konay segment 1 - D (541)', 'Avalinguo - Dana and Konay segment 1 - D (540)', 'Avalinguo - Dana and Konay segment 1 - D (539)', 'Avalinguo - Dana and Konay segment 1 - D (538)', 'Avalinguo - Dana and Konay segment 1 - D (537)', 'Avalin ...

# %%
from os import walk
from os import path

for (dirpath, dirnames, filenames) in walk("//content/audio-data/audio-data/high/"):
  print(filenames)
  for i in range(len(filenames)):
    os.rename("/content/audio-data/audio-data/high/"+filenames[i],"/content/audio-data/audio-data/high/"+filenames[i] + '.wav')
# Out:
# ['Avalinguo - Gonzalo and Eddy segment 24', 'chunk2305.wav', 'chunk391.wav', 'Wonderful Abstract Notions segment 169', 'chunk196.wav', 'chunk809.wav', 'chunk2383.wav', 'chunk386.wav', 'Elderly Chinese street cleaner speaks fluent English segment 44 - G', 'Wonderful Abstract Notions segment 90', 'Wonderful Abstract Notions segment 236', 'chunk2431.wav', 'chunk947.wav', 'chunk2413.wav', 'Wonderful Abstract Notions segment 180', 'chunk1181.wav', 'Wonderful Abstract Notions segment 200', 'chunk1720.wav', 'chunk740.wav', 'chunk2016.wav', 'chunk575.wav', 'chunk1783.wav', 'chunk2191.wav', 'Avalinguo - Alan and Eduardo segment 6 - A', 'chunk1937.wav', 'chunk1122.wav', 'chunk2213.wav', 'chunk2364.wav', 'Wonderful Abstract Notions segment 199', 'Wonderful Abstract Notions segment 91', 'Avalinguo_Manuel_and_Dayana segment 61', 'chunk212.wav', 'chunk2448.wav', 'Wonderful Abstract Notions segment 155', 'chunk2222.wav', 'Avalinguo - Alan and Eduardo segment 19 - A', 'chunk892.wav', 'chunk285.wav', 'chunk1369.wav', 'chunk926.wav', 'chunk28.wav', 'chunk2022.wav', 'chunk432.wav', 'chunk2075.wav', 'Wonderful Abstract Notions segment 19', 'chunk2122.wav', 'chunk2216.wav', 'chunk1446.wav', 'Wonderful Abstract Notions segment 131', 'chunk811.wav', 'Avalinguo - Gonzalo and Eddy segment 41', 'Avalinguo - Conversation 3 segment 32', 'Avalinguo - Alan and Eduardo segment 61 - E', 'Wonderful Abstract Notions segment 203', 'Avalinguo - Alan and Eduardo segment 118 - E', 'Avalinguo - Gonzalo and Eddy segment 48', 'chunk1811.wav', 'Avalinguo - Gonzalo and Eddy segment 52', 'chunk1926.wav', 'chunk2235.wav', 'chunk497.wav', 'chunk2281.wav', 'chunk2310.wav', 'chunk670.wav', 'chunk1866.wav', 'chunk16.wav', 'Wonderful Abstract Notions segment 10', 'Avalinguo_Manuel_and_Dayana segment 28', 'Avalinguo - Gonzalo and Eddy segment 42', 'chunk60.wav', 'Avalinguo - Conversation 6 segment 9', 'chunk882.wav', 'chunk429.wav', 'chunk1278.wav', 'Wonderful Abstract Notions segment 86', 'chunk1133.wav', 'chunk1778.wav', 'chunk472.wav', 'chunk154.wav', 'chunk1510.wav', 'chunk597.wav', 'Wonderful Abstract Notions segment 82', 'Avalinguo - Gonzalo and Eddy segment 81', 'Avalinguo - Gonzalo and Eddy segment 86', 'chunk198.wav', 'chunk1228.wav', 'Avalinguo - Xoca and Josué segment 16 - X', 'chunk997.wav', 'chunk337.wav', 'Avalinguo - Dana and Konay segment 6 - K', 'chunk551.wav', 'chunk2061.wav', 'chunk228.wav', 'chunk1267.wav', 'chunk2164.wav', 'chunk853.wav', 'Luis Suarez interview in English after being awarded November player of the month segment 7 - L', 'Avalinguo - Conversation 1 segment 23', 'Avalinguo_Manuel_and_Dayana segment 18', 'chunk2430.wav', 'chunk1763.wav', 'Wonderful Abstract Notions segment 59', 'Wonderful Abstract Notions segment 185', 'chunk1359.wav', 'Avalinguo_Manuel_and_Dayana segment 54', 'Avalinguo - Alan and Eduardo segment 74 - E', 'chunk781.wav', 'Wonderful Abstract Notions segment 181', 'chunk1790.wav', 'Avalinguo - Conversation 6 segment 36', 'Avalinguo_Manuel_and_Dayana segment 11', 'chunk1039.wav', 'Elderly Chinese street cleaner speaks fluent English segment 16 - G', 'Luis Suarez interview in English after being awarded November player of the month segment 27 - L', 'Avalinguo - Conversation 2 segment 13', 'chunk2373.wav', 'chunk1094.wav', 'chunk1260.wav', 'Avalinguo - Alan and Eduardo segment 21 - E', 'Avalinguo - Alan and Eduardo segment 87 - A', 'chunk542.wav', 'Angela_merkel_speaking_english_to_british_parliament segment 9', 'chunk1652.wav', 'Luis Suarez interview in English after being awarded November player of the month segment 18 - W', 'chunk1275.wav', 'chunk1569.wav', 'Wonderful Abstract Notions segment 121', 'chunk125.wav', 'chunk2302.wav', 'chunk349.wav', 'chunk1565.wav', 'Avalinguo - Gonzalo and Eddy segment 107', 'chunk1384.wav', 'chunk1078.wav', 'chunk1197.wav', 'Avalinguo_Manuel_and_Dayana segment 79', 'chunk2134.wav', 'chunk916.wav', 'Avalinguo - Alan and Eduardo segment 101 - A', 'chunk301.wav', 'chunk362.wav', 'Wonderful Abstrac ...

# %%
from os import walk
from os import path

for (dirpath, dirnames, filenames) in walk("/content/audio-data/audio-data/low_1"):
  print(filenames)
  for i in range(len(filenames)):
    os.rename("/content/audio-data/audio-data/low_1/"+filenames[i],"/content/audio-data/audio-data/low_1/"+filenames[i] + '.wav')
# Out:
# ['Avalinguo - Victor and Abraham segment 118.mp3', 'chunk970.wav.mp3', 'chunk1107.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (861).mp3', 'chunk292.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (603).mp3', 'chunk286.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (474).mp3', 'Avalinguo - Victor and Abraham segment 102.mp3', 'chunk1050.wav.mp3', 'chunk528.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (699).mp3', 'Avalinguo - Dana and Konay segment 1 - D (747).mp3', 'Avalinguo - Victor and Abraham segment 63.mp3', 'chunk586.wav.mp3', 'chunk585.wav.mp3', 'chunk76.wav.mp3', 'chunk156.wav.mp3', 'Avalinguo - Xoca and Josué segment 58 - J.mp3', 'chunk184.wav.mp3', 'chunk717.wav.mp3', 'chunk177.wav.mp3', 'Avalinguo - Dana and Konay segment 32 - D.mp3', 'Avalinguo - Victor and Abraham segment 13.mp3', 'Avalinguo - Dana and Konay segment 1 - D (838).mp3', 'chunk481.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (449).mp3', 'Avalinguo - Dana and Konay segment 118 - D.mp3', 'Avalinguo - Dana and Konay segment 1 - D (642).mp3', 'Avalinguo - Victor and Abraham segment 76.mp3', 'chunk345.wav.mp3', 'chunk51.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (856).mp3', 'chunk89.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (609).mp3', 'Avalinguo - Dana and Konay segment 1 - D (718).mp3', 'chunk288.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (707).mp3', 'chunk369.wav.mp3', 'chunk491.wav.mp3', 'chunk159.wav.mp3', 'Avalinguo - Xoca and Josué segment 8 - J.mp3', 'chunk1065.wav.mp3', 'Elderly Chinese street cleaner speaks fluent English segment 55 - E.mp3', 'Avalinguo - Dana and Konay segment 96 - D.mp3', 'chunk642.wav.mp3', 'chunk385.wav.mp3', 'chunk260.wav.mp3', 'Avalinguo - Victor and Abraham segment 44.mp3', 'chunk979.wav.mp3', 'chunk257.wav.mp3', 'chunk704.wav.mp3', 'chunk98.wav.mp3', 'chunk605.wav.mp3', 'chunk1071.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (627).mp3', 'Avalinguo - Dana and Konay segment 51 - D.mp3', 'chunk454.wav.mp3', 'chunk455.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (689).mp3', 'chunk764.wav.mp3', 'Avalinguo - Victor and Abraham segment 133.mp3', 'chunk322.wav.mp3', 'chunk387.wav.mp3', 'chunk639.wav.mp3', 'Avalinguo - Victor and Abraham segment 12.mp3', 'Avalinguo - Dana and Konay segment 1 - D (710).mp3', 'chunk254.wav.mp3', 'Avalinguo - Dana and Konay segment 65 - D.mp3', 'Avalinguo - Dana and Konay segment 110 - D.mp3', 'chunk907.wav.mp3', 'chunk640.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (514).mp3', 'Avalinguo - Dana and Konay segment 1 - D (537).mp3', 'chunk100.wav.mp3', 'Avalinguo - Victor and Abraham segment 134.mp3', 'chunk714.wav.mp3', 'chunk379.wav.mp3', 'chunk497.wav.mp3', 'Avalinguo - Dana and Konay segment 74 - D.mp3', 'chunk649.wav.mp3', 'Avalinguo - Itzel and Friend segment 67 - I.mp3', 'chunk1108.wav.mp3', 'Elderly Chinese street cleaner speaks fluent English segment 48 - E.mp3', 'Avalinguo - Itzel and Friend segment 7 - I.mp3', 'Avalinguo - Xoca and Josué segment 45 - J.mp3', 'chunk133.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (498).mp3', 'chunk355.wav.mp3', 'chunk29.wav.mp3', 'chunk31.wav.mp3', 'chunk172.wav.mp3', 'chunk1012.wav.mp3', 'chunk716.wav.mp3', 'Avalinguo - Dana and Konay segment 1 - D (535).mp3', 'Avalinguo - Dana and Konay segment 1 - D (687).mp3', 'Avalinguo - Itzel and Friend segment 42 - I.mp3', 'Avalinguo - Victor and Abraham segment 37.mp3', 'chunk1073.wav.mp3', 'chunk777.wav.mp3', 'Avalinguo - Dana and Konay segment 64 - D.mp3', 'chunk282.wav.mp3', 'chunk48.wav.mp3', 'chunk580.wav.mp3', 'chunk5.wav.mp3', 'chunk763.wav.mp3', 'Avalinguo - Victor and Abraham segment 105.mp3', 'Elderly Chinese street cleaner speaks fluent English segment 70 - E.mp3', 'chunk26.wav.mp3', 'chunk1081.wav.mp3', 'Elderly Chinese street cleaner speaks fluent English segment 61 - E.mp3', 'chunk945.wav.mp3', 'chunk359.wav.mp3', 'chunk487.wav.mp3', 'Avalinguo - Victor and Abraham segment 74.mp3', 'chunk1047.wav.mp3', 'chunk191.wa ...

# %%
features, labels = parse_audio_files('/content/audio-data/audio-data/high', audio_subdirectories) #(parent dir,sub dirs)
np.save('feat.npy', features) 
np.save('label.npy', labels)
# Out:
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 17.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk987.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk845.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Itzel and Friend segment 52 - F.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 82 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 165.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1590.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1752.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1961.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk516.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1385.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 25 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 39 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1310.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk638.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1585.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk369.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1743.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk281.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1914.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk553.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1124.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2243.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2468.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 104.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1632.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk364.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1511.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk253.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2219.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2470.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 65.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk46.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk779.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 60.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 114.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk441.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2146.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk873.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 170.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1699.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk864.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 32.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2211.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 57 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2417.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2209.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1825.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2358.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1119.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2270.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1093.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk804.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1245.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1001.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk393.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1960.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1000.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2467.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1010.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1413.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk646.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1793.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Luis Suarez interview in English after being awarded November player of the month segment 10 - L.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2032.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1923.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Itzel and Friend segment 64 - F.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2006.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 225.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2302.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 36.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 140.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2342.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk718.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2424.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 54 - A.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Xoca and Josué segment 23 - X.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2128.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1537.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 31.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk406.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1073.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 13.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1690.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 10 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2306.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 192.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk928.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk286.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 131.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk814.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1649.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk878.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 66 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 126.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk763.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1842.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1635.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 88.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk65.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 31.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2021.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 6.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk8.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1412.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Luis Suarez interview in English after being awarded November player of the month segment 6 - Luis.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1284.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk952.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk617.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 42 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 60 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2072.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 60.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1314.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 71.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1396.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2235.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1710.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2203.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk524.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1040.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1950.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Angela_merkel_speaking_english_to_british_parliament segment 12.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 98.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 1 segment 29.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2446.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk401.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2389.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2281.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1228.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 4.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 70 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2274.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 5.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 82.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1429.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk485.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1651.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 23.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1432.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2113.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk436.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1766.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 122.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2175.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 41.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 61.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 26.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1335.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2459.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 45 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1639.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2171.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Xoca and Josué segment 101 - X.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 75.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Itzel and Friend segment 38 - F.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 220.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk376.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 56.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk507.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Elderly Chinese street cleaner speaks fluent English segment 16 - G.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk450.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk344.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk210.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 47.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk97.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Angela_merkel_speaking_english_to_british_parliament segment 13.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk732.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 229.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk905.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2166.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2232.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 35.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 112.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1514.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk420.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 1 segment 34.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Dana and Konay segment 50 - K.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Xoca and Josué segment 96 - X.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1937.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1711.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1949.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 1 segment 26.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 19.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk721.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk429.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1216.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk417.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 15.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1493.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1224.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 4.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1665.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk25.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2471.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk194.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk428.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 3.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 196.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1084.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2149.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 179.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk102.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk772.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1246.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 2 segment 24.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk80.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1252.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1753.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 169.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2351.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1078.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk83.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1652.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 121.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 15.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1063.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 205.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk477.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2374.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 48.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Xoca and Josué segment 81 - X.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk846.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 8.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Luis Suarez interview in English after being awarded November player of the month segment 21 - L.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1418.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk225.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 23.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1578.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 24 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 33.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2338.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 107.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk727.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk532.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk56.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk963.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 27 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Angela_merkel_speaking_english_to_british_parliament segment 9.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1897.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1134.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 21 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk966.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk851.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 102.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk388.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2167.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk733.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk824.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1707.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1905.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk635.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 46 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 22 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk81.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 2 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Dana and Konay segment 49 - K.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1196.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1584.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1624.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Dana and Konay segment 89 - K.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1708.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1689.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1810.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk195.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1544.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk971.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 12.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk204.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 80.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk336.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 157.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1168.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1519.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1867.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk652.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1261.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk211.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1455.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk64.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk382.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2188.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk455.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk181.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk764.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1898.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2482.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1354.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1326.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 83.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2433.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk237.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2237.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1890.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1298.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1477.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2484.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2362.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2212.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1357.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1685.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2145.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 40.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk62.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1081.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk29.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1121.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk186.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 108.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1057.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk992.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2124.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1817.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Dana and Konay segment 106 - K.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk657.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1560.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk148.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk201.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1347.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk331.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2178.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1508.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1315.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 38.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 232.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1036.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk631.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 80.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Gonzalo and Eddy segment 129.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2002.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1828.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk50.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2017.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 124.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1780.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 80 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Interview with a Filippines Woman segment 36 - M.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk416.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk229.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk215.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 41.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 98 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk103.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk757.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1495.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Itzel and Friend segment 19 - F.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1361.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk893.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1808.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk297.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk752.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk938.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk589.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2303.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk112.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2228.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2090.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1219.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1458.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1317.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk410.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk536.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk530.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk558.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk870.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo_Manuel_and_Dayana segment 79.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1568.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2220.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk2334.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1995.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk394.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk414.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1229.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1501.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 16.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk2477.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 14.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 1 segment 21.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/Wonderful Abstract Notions segment 63.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 6 segment 40.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1319.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Conversation 3 segment 32.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk549.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/Avalinguo - Alan and Eduardo segment 53 - E.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/high/chunk1087.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk1225.wav.wav
# Actual File Name:  /content/audio-data/audio-data/high/chunk839.wav.wav
# ...
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 95.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk978.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk20.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk398.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Itzel and Friend segment 14 - I.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk355.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk205.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (634).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk11.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk376.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk833.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk777.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk251.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (662).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk16.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1119.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk697.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk725.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (631).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk834.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk753.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk629.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (626).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 73 - D.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Xoca and Josué segment 74 - J.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Xoca and Josué segment 47 - J.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 116.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk741.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Itzel and Friend segment 10 - I.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk781.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk742.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 57.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk103.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk975.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk394.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 47 - D.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1093.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1051.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Itzel and Friend segment 45 - I.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk606.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 83.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Itzel and Friend segment 46 - I.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk75.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk91.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk418.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk264.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk113.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk540.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk580.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 99.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1052.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk487.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1102.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (446).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk839.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk232.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk378.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Xoca and Josué segment 26 - J.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 123 - D.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Xoca and Josué segment 116 - J.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk559.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 74.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk109.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk82.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (875).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 32.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk768.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (855).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk552.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk516.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (733).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Victor and Abraham segment 20.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk41.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk599.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Elderly Chinese street cleaner speaks fluent English segment 61 - E.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk538.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (541).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Elderly Chinese street cleaner speaks fluent English segment 47 - E.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (777).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk537.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (802).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (783).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1082.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk59.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (805).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk900.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk329.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (737).mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk204.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Elderly Chinese street cleaner speaks fluent English segment 31 - E.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1100.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk126.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk847.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk273.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1072.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk1009.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk981.wav.mp3.wav
# Actual File Name:  /content/audio-data/audio-data/low_1/Avalinguo - Xoca and Josué segment 106 - J.mp3.wav
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Actual File Name:  /content/audio-data/audio-data/low_1/chunk506.wav.mp3.wav
# Extracted features from low_1, done

# %%
# !pwd
# Out:
# /content

# %%
# !cp -R /content/drive/MyDrive/audio-data/ /content/audio-data/
# Out:
# ^C

# %%
# !pwd
# Out:
# /content

# %%
mv /content/drive/MyDrive/audio-data /content/audio-data/

# %%
print (len(features))
# Out:
# 5465

# %%
#Load np files
import numpy as np
features= np.load('feat.npy')
print(len(features[1]))
# Out:
# 23

# %%
import numpy as np
features= np.load('feat.npy')

#Pandas dataframe with N features for each audio
import pandas as pd
df = pd.DataFrame(features)
df.head()
# Out:
#            0           1          2   ...        20        21        22
# 0 -432.551880  125.501030  -3.472781  ...  0.017995  1.672480  0.060628
# 1 -467.902130  153.689850 -14.743220  ...  0.011283  1.598411  0.064957
# 2 -451.307678  112.377060  15.053312  ...  0.017073  1.554718  0.043421
# 3 -381.288574  162.799942 -42.634418  ...  0.017923  1.272350  0.057083
# 4 -284.514526  159.727997 -13.643111  ...  0.066239  1.467703  0.052055
#
# [5 rows x 23 columns]

# %%
labels = np.load('label.npy') 
print(labels)

# For future label de-encoding
label_classes = np.array(['Low','High'])
print(label_classes)
# Out:
# [0 0 0 ... 1 1 1]
# ['Low' 'High']

# %%
np.unique(labels)
# Out:
# array([0, 1])

# %%
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(13, 6))
librosa.display.specshow(features, x_axis='time')
plt.colorbar()
plt.title('MFCCs = 5 Values for 5s Audio Frames (High Class)')
plt.tight_layout()
plt.savefig('test saving.png')

# %%
features.shape 
len(features[1])
# Out:
# 23

# %%
#visulasisation of spectrogram
import matplotlib.pyplot as plt
y , sr = librosa.load('/content/audio-data/audio-data/low_1/Avalinguo - Dana and Konay segment 1 - D (493).mp3.wav', sr=None) # Using my own audio segment
plt.figure(figsize=(20, 15))
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max) 
librosa.display.specshow(D, y_axis='linear') 
#plt.colorbar(format='%+2.0f dB')
#plt.title('Linear-frequency power spectrogram')
#plt.subplot(4, 2, 2)
librosa.display.specshow(D, y_axis='log') 
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
C = librosa.feature.chroma_cqt(y=y, sr=sr)
plt.subplot(4, 2, 3)
librosa.display.specshow(C, y_axis='chroma')
plt.colorbar()
plt.title('Chromagram')
plt.subplot(4, 2, 4)
librosa.display.specshow(D, cmap='gray_r', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear power spectrogram (grayscale)')
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# Text(0.5, 1.0, 'Linear power spectrogram (grayscale)')

# %%
# MLP
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

# Fix random seed number
np.random.seed(7)

# Load the data
X = np.load('feat.npy')
y = np.load('label.npy').ravel() #Return a contiguous flattened array.

number_of_features = len(X[1]) #This is variable with each run
number_of_classes = 3

# Sample data randomly
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0) #70% Train, 30% Test

# Neural Network Architecture
model = Sequential() # Define Sequential model

# Using relu on the first two layers and softmax on the output layer

# 1st Layer
#N neurons, Number_Fatures-dimensional vectors
model.add(Dense(512, input_dim=number_of_features, activation='relu')) #32, 64, 128, 256, 512, 1024
model.add(Dropout(0.5))

# 2nd Layer
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

# 3rd Layer. Output 3 neurons corresponding the number of classes
model.add(Dense(number_of_classes, activation='softmax'))

# Model Compilation. Loss for multi-class classification problem
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rmsprop = 'rmsprop'
adam = 'adam'
model.compile(loss='categorical_crossentropy',
              optimizer= rmsprop, #rmsprop better than sgd
              metrics=['accuracy'])

# Convert labels to categorical one-hot encoding
y_train = keras.utils.to_categorical(y_train-1, num_classes= number_of_classes) # Convert class vector into binary Matrix
y_test = keras.utils.to_categorical(y_test-1, num_classes= number_of_classes)

# Train and test
model.fit(X_train, y_train, epochs=300, batch_size=64) #batch 32, 64, 128, 256, 512
score, acc = model.evaluate(X_test, y_test, batch_size=64)
# Out:
# Epoch 1/300
# 60/60 [==============================] - 3s 3ms/step - loss: 19.1053 - accuracy: 0.6195
# Epoch 2/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.1221 - accuracy: 0.7492
# Epoch 3/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7568 - accuracy: 0.7965
# Epoch 4/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4649 - accuracy: 0.8268
# Epoch 5/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3710 - accuracy: 0.8515
# Epoch 6/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2879 - accuracy: 0.8859
# Epoch 7/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2458 - accuracy: 0.9074
# Epoch 8/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2159 - accuracy: 0.9115
# Epoch 9/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2004 - accuracy: 0.9294
# Epoch 10/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1758 - accuracy: 0.9308
# Epoch 11/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1768 - accuracy: 0.9313
# Epoch 12/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9474
# Epoch 13/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1494 - accuracy: 0.9466
# Epoch 14/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1642 - accuracy: 0.9416
# Epoch 15/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1272 - accuracy: 0.9553
# Epoch 16/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9479
# Epoch 17/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1402 - accuracy: 0.9529
# Epoch 18/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9603
# Epoch 19/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9529
# Epoch 20/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1206 - accuracy: 0.9499
# Epoch 21/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1216 - accuracy: 0.9562
# Epoch 22/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1172 - accuracy: 0.9624
# Epoch 23/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9594
# Epoch 24/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9526
# Epoch 25/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1152 - accuracy: 0.9573
# Epoch 26/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9561
# Epoch 27/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1211 - accuracy: 0.9621
# Epoch 28/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1080 - accuracy: 0.9675
# Epoch 29/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9657
# Epoch 30/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1069 - accuracy: 0.9616
# Epoch 31/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9637
# Epoch 32/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1086 - accuracy: 0.9580
# Epoch 33/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1133 - accuracy: 0.9584
# Epoch 34/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1048 - accuracy: 0.9695
# Epoch 35/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9634
# Epoch 36/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9663
# Epoch 37/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.9669
# Epoch 38/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0896 - accuracy: 0.9630
# Epoch 39/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9602
# Epoch 40/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9737
# Epoch 41/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9638
# Epoch 42/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0799 - accuracy: 0.9685
# Epoch 43/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1006 - accuracy: 0.9666
# Epoch 44/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9744
# Epoch 45/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.9672
# Epoch 46/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9763
# Epoch 47/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9657
# Epoch 48/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0903 - accuracy: 0.9668
# Epoch 49/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9761
# Epoch 50/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.9645
# Epoch 51/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0988 - accuracy: 0.9683
# Epoch 52/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9719
# Epoch 53/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0903 - accuracy: 0.9712
# Epoch 54/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9666
# Epoch 55/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9746
# Epoch 56/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9704
# Epoch 57/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.9698
# Epoch 58/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0858 - accuracy: 0.9731
# Epoch 59/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9748
# Epoch 60/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0882 - accuracy: 0.9696
# Epoch 61/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1071 - accuracy: 0.9678
# Epoch 62/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9745
# Epoch 63/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 0.9823
# Epoch 64/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9740
# Epoch 65/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.9671
# Epoch 66/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9752
# Epoch 67/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9696
# Epoch 68/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9721
# Epoch 69/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9743
# Epoch 70/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9750
# Epoch 71/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9775
# Epoch 72/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9718
# Epoch 73/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9662
# Epoch 74/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9731
# Epoch 75/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9720
# Epoch 76/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9736
# Epoch 77/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0872 - accuracy: 0.9748
# Epoch 78/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9731
# Epoch 79/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9780
# Epoch 80/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9733
# Epoch 81/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9696
# Epoch 82/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9762
# Epoch 83/300
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9734
# Epoch 84/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9772
# Epoch 85/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9779
# Epoch 86/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9746
# Epoch 87/300
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0846 - accuracy: 0.9721
# Epoch 88/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 0.9752
# Epoch 89/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0930 - accuracy: 0.9746
# Epoch 90/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0751 - accuracy: 0.9691
# Epoch 91/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0842 - accuracy: 0.9709
# Epoch 92/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 0.9774
# Epoch 93/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 0.9740
# Epoch 94/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9800
# Epoch 95/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0810 - accuracy: 0.9723
# Epoch 96/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9754
# Epoch 97/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0686 - accuracy: 0.9741
# Epoch 98/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9756
# Epoch 99/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0551 - accuracy: 0.9802
# Epoch 100/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9781
# Epoch 101/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9767
# Epoch 102/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 0.9775
# Epoch 103/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9713
# Epoch 104/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9780
# Epoch 105/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9789
# Epoch 106/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 0.9802
# Epoch 107/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9768
# Epoch 108/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9790
# Epoch 109/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0745 - accuracy: 0.9735
# Epoch 110/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9789
# Epoch 111/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0693 - accuracy: 0.9750
# Epoch 112/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9740
# Epoch 113/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9735
# Epoch 114/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9758
# Epoch 115/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.9812
# Epoch 116/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9750
# Epoch 117/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9778
# Epoch 118/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9754
# Epoch 119/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0716 - accuracy: 0.9748
# Epoch 120/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9802
# Epoch 121/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0512 - accuracy: 0.9827
# Epoch 122/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9749
# Epoch 123/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9753
# Epoch 124/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9789
# Epoch 125/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9776
# Epoch 126/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9729
# Epoch 127/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 0.9747
# Epoch 128/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9734
# Epoch 129/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 0.9807
# Epoch 130/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9801
# Epoch 131/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9705
# Epoch 132/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9746
# Epoch 133/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 0.9827
# Epoch 134/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9805
# Epoch 135/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0509 - accuracy: 0.9821
# Epoch 136/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9759
# Epoch 137/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9663
# Epoch 138/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 0.9745
# Epoch 139/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9796
# Epoch 140/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9731
# Epoch 141/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.9744
# Epoch 142/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0682 - accuracy: 0.9747
# Epoch 143/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9824
# Epoch 144/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9814
# Epoch 145/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9772
# Epoch 146/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0553 - accuracy: 0.9796
# Epoch 147/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9811
# Epoch 148/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 0.9781
# Epoch 149/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 0.9815
# Epoch 150/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 0.9796
# Epoch 151/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0494 - accuracy: 0.9829
# Epoch 152/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9769
# Epoch 153/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9799
# Epoch 154/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9786
# Epoch 155/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9803
# Epoch 156/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 0.9841
# Epoch 157/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9748
# Epoch 158/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0547 - accuracy: 0.9804
# Epoch 159/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9761
# Epoch 160/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 0.9758
# Epoch 161/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 0.9789
# Epoch 162/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9818
# Epoch 163/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9775
# Epoch 164/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 0.9782
# Epoch 165/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9767
# Epoch 166/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0841 - accuracy: 0.9770
# Epoch 167/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9733
# Epoch 168/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9766
# Epoch 169/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9724
# Epoch 170/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9764
# Epoch 171/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9783
# Epoch 172/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9800
# Epoch 173/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9775
# Epoch 174/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9811
# Epoch 175/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 0.9826
# Epoch 176/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.9829
# Epoch 177/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 0.9811
# Epoch 178/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0481 - accuracy: 0.9840
# Epoch 179/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 0.9819
# Epoch 180/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0730 - accuracy: 0.9785
# Epoch 181/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9764
# Epoch 182/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9759
# Epoch 183/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 0.9764
# Epoch 184/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9774
# Epoch 185/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9773
# Epoch 186/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9786
# Epoch 187/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9806
# Epoch 188/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9774
# Epoch 189/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9828
# Epoch 190/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9834
# Epoch 191/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 0.9768
# Epoch 192/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9831
# Epoch 193/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9792
# Epoch 194/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9836
# Epoch 195/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 0.9838
# Epoch 196/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9798
# Epoch 197/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9826
# Epoch 198/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9772
# Epoch 199/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9849
# Epoch 200/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1005 - accuracy: 0.9786
# Epoch 201/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0550 - accuracy: 0.9815
# Epoch 202/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9763
# Epoch 203/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9774
# Epoch 204/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9774
# Epoch 205/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9815
# Epoch 206/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 0.9747
# Epoch 207/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0499 - accuracy: 0.9821
# Epoch 208/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9813
# Epoch 209/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9827
# Epoch 210/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9820
# Epoch 211/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9790
# Epoch 212/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9830
# Epoch 213/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 0.9806
# Epoch 214/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9832
# Epoch 215/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9846
# Epoch 216/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.9804
# Epoch 217/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9786
# Epoch 218/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9805
# Epoch 219/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9816
# Epoch 220/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9807
# Epoch 221/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9760
# Epoch 222/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0517 - accuracy: 0.9799
# Epoch 223/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9790
# Epoch 224/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9833
# Epoch 225/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9757
# Epoch 226/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9772
# Epoch 227/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0644 - accuracy: 0.9822
# Epoch 228/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 0.9831
# Epoch 229/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 0.9811
# Epoch 230/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9796
# Epoch 231/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0796 - accuracy: 0.9780
# Epoch 232/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0477 - accuracy: 0.9852
# Epoch 233/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9853
# Epoch 234/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9871
# Epoch 235/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9832
# Epoch 236/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0592 - accuracy: 0.9800
# Epoch 237/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.9763
# Epoch 238/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0512 - accuracy: 0.9842
# Epoch 239/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9827
# Epoch 240/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9792
# Epoch 241/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9794
# Epoch 242/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 0.9821
# Epoch 243/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 0.9792
# Epoch 244/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0613 - accuracy: 0.9808
# Epoch 245/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9817
# Epoch 246/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9858
# Epoch 247/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 0.9809
# Epoch 248/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9852
# Epoch 249/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9823
# Epoch 250/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9860
# Epoch 251/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9825
# Epoch 252/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9862
# Epoch 253/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0778 - accuracy: 0.9784
# Epoch 254/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9836
# Epoch 255/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9862
# Epoch 256/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9808
# Epoch 257/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 0.9797
# Epoch 258/300
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9883
# Epoch 259/300
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9841
# Epoch 260/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9857
# Epoch 261/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0631 - accuracy: 0.9801
# Epoch 262/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9806
# Epoch 263/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9811
# Epoch 264/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9868
# Epoch 265/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9804
# Epoch 266/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9817
# Epoch 267/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 0.9851
# Epoch 268/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9814
# Epoch 269/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0512 - accuracy: 0.9873
# Epoch 270/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 0.9835
# Epoch 271/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9810
# Epoch 272/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9847
# Epoch 273/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9818
# Epoch 274/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9850
# Epoch 275/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9811
# Epoch 276/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9826
# Epoch 277/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 0.9804
# Epoch 278/300
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0737 - accuracy: 0.9773
# Epoch 279/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.9785
# Epoch 280/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9840
# Epoch 281/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9791
# Epoch 282/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9815
# Epoch 283/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9818
# Epoch 284/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9790
# Epoch 285/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9825
# Epoch 286/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0714 - accuracy: 0.9844
# Epoch 287/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9823
# Epoch 288/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9853
# Epoch 289/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 0.9805
# Epoch 290/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 0.9811
# Epoch 291/300
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9824
# Epoch 292/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 0.9748
# Epoch 293/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9788
# Epoch 294/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9824
# Epoch 295/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9756
# Epoch 296/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9813
# Epoch 297/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9788
# Epoch 298/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.9840
# Epoch 299/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9839
# Epoch 300/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9824
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9835

# %%
print ('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Test score: 0.0701020136475563
# Test accuracy: 0.9835366010665894

# %%
#Load data from generated numpy files
X = np.load('feat.npy') # list of features
y = np.load('label.npy').ravel() # labels are the target

# %%
import numpy as np
np.unique(y)
# Out:
# array([0, 1])

# %%
X = np.load('feat.npy') # list of features
y = np.load('label.npy').ravel()

# %%
from sklearn.ensemble import RandomForestClassifier #Random Forest classifier
import pandas as pd 
import numpy as np
np.random.seed(7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=6)

# Initialize classifier
rf_clf = RandomForestClassifier(n_estimators=350, n_jobs=2, random_state=6, max_features="auto") 

# Train model
rf_clf.fit(X_train, y_train)

# Make predictions
y_prediction = rf_clf.predict(X_test)

# Evaluate accuracy
acc = rf_clf.score(X_test, y_test) 
print ("Accuracy = %0.5f" %acc)
# Out:
# Accuracy = 0.98537

# %%
prediction_decoded = label_classes[y_prediction]
actual_value_decoded = label_classes[y_test]

## Confusion Matrix
pd.crosstab(actual_value_decoded, prediction_decoded)
# Out:
# col_0  High   Low
# row_0
# High    610     8
# Low      16  1006

# %%
import numpy as np 
import sklearn
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

#Load data from generated numpy files
X = np.load('feat.npy') # list of features
y = np.load('label.npy').ravel() # labels are the target

# Fix random seed number
np.random.seed(7)

# Load the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=30) 
# Data scaling 
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.astype(np.float32))
X_test_scaled = scaler.transform(X_test.astype(np.float32))

# SVM classifier
svm_clf = SVC(C=200, gamma = 0.0001, kernel='rbf', decision_function_shape="ovr") 
#svm_clf = LinearSVC(random_state=42) # HandsOn git

# Fit model
svm_clf.fit(X_train, y_train) #From Beif github
#svm_clf.fit(X_train_scaled, y_train) # HandsOn book

# Predictions
y_predict = svm_clf.predict(X_test)


# Accuracy Result
acc = svm_clf.score(X_test, y_test) # From Beif github
print
print("Final accuracy = %0.4f" %acc)
#print('\n')
# Out:
# Final accuracy = 0.9799

# %%
prediction_decoded = label_classes[y_predict]
actual_value_decoded = label_classes[y_test]

# %%
pd.crosstab(actual_value_decoded, prediction_decoded)
# Out:
# col_0  High   Low
# row_0
# High    575    16
# Low      17  1032

# %%
##1-D  convolution can be applied to audio signal

import numpy as np
import keras 
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

# Load data 
X = np.load("feat.npy")
y = np.load('label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1]) 
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 233)

# Need to reshape you data to have a spatial dimension for Conv1d to make sense
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# Neural Network Construction
model = Sequential()

# Neural Network Architecture
# first layer has 64 convolution filters 
model.add(Conv1D(64, 3, activation='relu', padding='same', input_shape = (number_of_features, 1))) 
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(3))
model.add(Conv1D(32, 3, padding='same', activation='relu'))
model.add(Conv1D(32, 3, padding='same', activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))

model.add(Dense(number_of_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# Convert label to onehot
y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Train Network
model.fit(X_train, y_train, batch_size=32, epochs=90)

# Evaluate model's accuracy with test data
score, acc = model.evaluate(X_test, y_test, batch_size=32) # Computes the loss & accuracy based on the input you pass it

print('Test score:', score) #loss
print('Test accuracy:', acc)
# Out:
# Epoch 1/90
# 120/120 [==============================] - 31s 5ms/step - loss: 1.0607 - accuracy: 0.6467
# Epoch 2/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.4070 - accuracy: 0.8255
# Epoch 3/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.3168 - accuracy: 0.8669
# Epoch 4/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.2739 - accuracy: 0.8837
# Epoch 5/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.2074 - accuracy: 0.9144
# Epoch 6/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.1852 - accuracy: 0.9250
# Epoch 7/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.9373
# Epoch 8/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.1461 - accuracy: 0.9464
# Epoch 9/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9498
# Epoch 10/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.1246 - accuracy: 0.9574
# Epoch 11/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.1276 - accuracy: 0.9576
# Epoch 12/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0945 - accuracy: 0.9631
# Epoch 13/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1064 - accuracy: 0.9596
# Epoch 14/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.1035 - accuracy: 0.9612
# Epoch 15/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0825 - accuracy: 0.9705
# Epoch 16/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0759 - accuracy: 0.9726
# Epoch 17/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0750 - accuracy: 0.9693
# Epoch 18/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0723 - accuracy: 0.9704
# Epoch 19/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0828 - accuracy: 0.9660
# Epoch 20/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0829 - accuracy: 0.9715
# Epoch 21/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0655 - accuracy: 0.9760
# Epoch 22/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0681 - accuracy: 0.9741
# Epoch 23/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 0.9768
# Epoch 24/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0721 - accuracy: 0.9739
# Epoch 25/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0680 - accuracy: 0.9748
# Epoch 26/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9752
# Epoch 27/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0526 - accuracy: 0.9830
# Epoch 28/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9745
# Epoch 29/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0503 - accuracy: 0.9844
# Epoch 30/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0577 - accuracy: 0.9805
# Epoch 31/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0653 - accuracy: 0.9775
# Epoch 32/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9802
# Epoch 33/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0368 - accuracy: 0.9867
# Epoch 34/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0423 - accuracy: 0.9843
# Epoch 35/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9820
# Epoch 36/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0454 - accuracy: 0.9832
# Epoch 37/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0480 - accuracy: 0.9852
# Epoch 38/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0376 - accuracy: 0.9866
# Epoch 39/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0436 - accuracy: 0.9844
# Epoch 40/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0448 - accuracy: 0.9850
# Epoch 41/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0448 - accuracy: 0.9841
# Epoch 42/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9875
# Epoch 43/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0340 - accuracy: 0.9876
# Epoch 44/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0340 - accuracy: 0.9886
# Epoch 45/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0651 - accuracy: 0.9840
# Epoch 46/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0430 - accuracy: 0.9865
# Epoch 47/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0295 - accuracy: 0.9880
# Epoch 48/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0370 - accuracy: 0.9862
# Epoch 49/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0365 - accuracy: 0.9862
# Epoch 50/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0395 - accuracy: 0.9849
# Epoch 51/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0400 - accuracy: 0.9881
# Epoch 52/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0363 - accuracy: 0.9875
# Epoch 53/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0428 - accuracy: 0.9874
# Epoch 54/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0335 - accuracy: 0.9889
# Epoch 55/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0310 - accuracy: 0.9927
# Epoch 56/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0282 - accuracy: 0.9897
# Epoch 57/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0335 - accuracy: 0.9902
# Epoch 58/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 0.9868
# Epoch 59/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9871
# Epoch 60/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9889
# Epoch 61/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0428 - accuracy: 0.9824
# Epoch 62/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0268 - accuracy: 0.9920
# Epoch 63/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0366 - accuracy: 0.9876
# Epoch 64/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0297 - accuracy: 0.9889
# Epoch 65/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0365 - accuracy: 0.9877
# Epoch 66/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0294 - accuracy: 0.9900
# Epoch 67/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0399 - accuracy: 0.9875
# Epoch 68/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9898
# Epoch 69/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 0.9915
# Epoch 70/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0311 - accuracy: 0.9918
# Epoch 71/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9875
# Epoch 72/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9918
# Epoch 73/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9865
# Epoch 74/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0593 - accuracy: 0.9870
# Epoch 75/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0269 - accuracy: 0.9908
# Epoch 76/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0334 - accuracy: 0.9878
# Epoch 77/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0373 - accuracy: 0.9906
# Epoch 78/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 0.9900
# Epoch 79/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0268 - accuracy: 0.9897
# Epoch 80/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0227 - accuracy: 0.9935
# Epoch 81/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0325 - accuracy: 0.9910
# Epoch 82/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 0.9936
# Epoch 83/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9886
# Epoch 84/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 0.9905
# Epoch 85/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0328 - accuracy: 0.9890
# Epoch 86/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0314 - accuracy: 0.9875
# Epoch 87/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9933
# Epoch 88/90
# 120/120 [==============================] - 0s 4ms/step - loss: 0.0637 - accuracy: 0.9868
# Epoch 89/90
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0320 - accuracy: 0.9918
# Epoch 90/90
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0369 - accuracy: 0.9902
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1156 - accuracy: 0.9793
# Test score: 0.11555402725934982
# Test accuracy: 0.9792683124542236

# %%
##LSTM 
import os
import numpy as np
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers import Dense
from keras.optimizers import Adam

# Load data 
X = np.load("feat.npy")
y = np.load('label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1]) 
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 230)


# Reshape data for LSTM (Samples, Timesteps, Features)
X_train = np.expand_dims(X_train, axis=2) #(280,193,1)
X_test = np.expand_dims(X_test, axis=2)

y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Build RNN Neural Network
print('Build LSTM RNN model ...')
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=X_train.shape[1:]))
model.add(LSTM(32, return_sequences=False))

#model.add(LSTM(16, return_sequences=False))
model.add(Dense(number_of_classes, activation='softmax'))
          
print("Compiling ...")
model.compile(loss='categorical_crossentropy', # for multiple classes
              optimizer='rmsprop', 
              metrics=['accuracy'])

print(model.summary())

print("Training ...")
model.fit(X_train, y_train, batch_size=64, epochs=60)

print("\nValidating ...")
score, accuracy = model.evaluate(X_test, y_test, batch_size=32, verbose=1)
print("Loss:  ", score)
print("Accuracy:  ", accuracy)
# Out:
# Build LSTM RNN model ...
# Compiling ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 23, 256)           264192
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                36992
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 301,283
# Trainable params: 301,283
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training ...
# Epoch 1/60
# 60/60 [==============================] - 3s 8ms/step - loss: 0.5957 - accuracy: 0.7286
# Epoch 2/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.4372 - accuracy: 0.8069
# Epoch 3/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.3795 - accuracy: 0.8261
# Epoch 4/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.2849 - accuracy: 0.8769
# Epoch 5/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.2391 - accuracy: 0.8922
# Epoch 6/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.2066 - accuracy: 0.9165
# Epoch 7/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1713 - accuracy: 0.9286
# Epoch 8/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.1655 - accuracy: 0.9365
# Epoch 9/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.1343 - accuracy: 0.9439
# Epoch 10/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9469
# Epoch 11/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1289 - accuracy: 0.9462
# Epoch 12/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.1079 - accuracy: 0.9610
# Epoch 13/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0886 - accuracy: 0.9597
# Epoch 14/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.9642
# Epoch 15/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0812 - accuracy: 0.9685
# Epoch 16/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0760 - accuracy: 0.9700
# Epoch 17/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0712 - accuracy: 0.9720
# Epoch 18/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0659 - accuracy: 0.9706
# Epoch 19/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0527 - accuracy: 0.9792
# Epoch 20/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0625 - accuracy: 0.9778
# Epoch 21/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0552 - accuracy: 0.9781
# Epoch 22/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0499 - accuracy: 0.9834
# Epoch 23/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0524 - accuracy: 0.9807
# Epoch 24/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0546 - accuracy: 0.9814
# Epoch 25/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0385 - accuracy: 0.9833
# Epoch 26/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0394 - accuracy: 0.9844
# Epoch 27/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0396 - accuracy: 0.9844
# Epoch 28/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0459 - accuracy: 0.9836
# Epoch 29/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0296 - accuracy: 0.9874
# Epoch 30/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0297 - accuracy: 0.9897
# Epoch 31/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.9865
# Epoch 32/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0345 - accuracy: 0.9882
# Epoch 33/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9905
# Epoch 34/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0399 - accuracy: 0.9871
# Epoch 35/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0226 - accuracy: 0.9919
# Epoch 36/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 0.9950
# Epoch 37/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 0.9890
# Epoch 38/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0298 - accuracy: 0.9902
# Epoch 39/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0180 - accuracy: 0.9928
# Epoch 40/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 0.9950
# Epoch 41/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0175 - accuracy: 0.9926
# Epoch 42/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0179 - accuracy: 0.9923
# Epoch 43/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0198 - accuracy: 0.9930
# Epoch 44/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 0.9982
# Epoch 45/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 0.9949
# Epoch 46/60
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0117 - accuracy: 0.9963
# Epoch 47/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 48/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 0.9966
# Epoch 49/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 0.9968
# Epoch 50/60
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 0.9987
# Epoch 51/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 0.9942
# Epoch 52/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9976
# Epoch 53/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 54/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9960
# Epoch 55/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0147 - accuracy: 0.9967
# Epoch 56/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9991
# Epoch 57/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0160 - accuracy: 0.9939
# Epoch 58/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9952
# Epoch 59/60
# 60/60 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 60/60
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9975
#
# Validating ...
# 52/52 [==============================] - 1s 4ms/step - loss: 0.1375 - accuracy: 0.9713
# Loss:   0.13754738867282867
# Accuracy:   0.9713414907455444
